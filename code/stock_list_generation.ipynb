# %%
import os
import numpy as np
import pandas as pd
from google.colab import drive

# Access drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Sentimental/'
stock_path = os.path.join(path, 'data', 'stock_list.csv')
# Out:
# Mounted at /content/drive

# %%
stocks = pd.read_csv(stock_path, index_col = 0)
stock_lst = [[company, stocks.loc[company, 'stock_code']] for company in stocks.index]
#stocks.loc['nvidia'] = 'NVDA'
stocks
# Out:
#                   stock_code
# apple                   AAPL
# tesla                   TSLA
# nvidia                  NVDA
# microsoft               MSFT
# amazon                  AMZN
# google                 GOOGL
# meta                    META
# netflix                 NFLX
# disney                   DIS
# visa                       V
# johnson & johnson        JNJ

# %%
#add 4 more
stocks.loc['microsoft'] = 'MSFT'
stocks.loc['amazon'] = 'AMZN'
stocks.loc['google'] = 'GOOGL'
stocks.loc['meta'] = 'META'
stocks
# Out:
#           stock_code
# apple           AAPL
# tesla           TSLA
# nvidia          NVDA
# microsoft       MSFT
# amazon          AMZN
# google         GOOGL
# meta            META

# %%
stocks.loc['netflix'] = 'NFLX'
stocks.loc['disney'] = 'DIS'

# %%
stocks.loc['visa'] = 'V'
stocks.loc['johnson & johnson'] = 'JNJ'

# %%
stocks.loc['jpmorgan chase & co.'] = 'JPM'
stocks.loc['bank of america'] = 'BAC'
stocks.loc['mastercard'] = 'MA'
stocks.loc['unitedhealth group'] = 'UNH'
stocks.loc['pfizer'] = 'PFE'

# %%
stocks.loc['home depot'] = 'HD'

# %%
stocks
# Out:
#                      stock_code
# apple                      AAPL
# tesla                      TSLA
# nvidia                     NVDA
# microsoft                  MSFT
# amazon                     AMZN
# google                    GOOGL
# meta                       META
# netflix                    NFLX
# disney                      DIS
# visa                          V
# johnson & johnson           JNJ
# jpmorgan chase & co.        JPM
# bank of america             BAC
# mastercard                   MA
# unitedhealth group          UNH
# pfizer                      PFE
# home depot                   HD

# %%
stocks.to_csv(stock_path)
